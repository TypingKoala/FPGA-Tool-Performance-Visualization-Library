# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

from ftpvl.evaluation import Evaluation
from ftpvl.fetchers import HydraFetcher
from ftpvl.processors import *
from ftpvl.styles import ColorMapStyle
from ftpvl.visualizers import SingleTableVisualizer

import seaborn as sns

# %%
# the ordered list of clock names to reference
hydra_clock_names = ["clk", "sys_clk", "clk_i"]

# specify how to convert toolchains to synthesis_tool/pr_tool
toolchain_map = {
    'vpr': ('yosys', 'vpr'),
    'vpr-fasm2bels': ('yosys', 'vpr'),
    'yosys-vivado': ('yosys', 'vivado'),
    'vivado': ('vivado', 'vivado'),
    'nextpnr-ice40': ('yosys', 'nextpnr'),
    'nextpnr-xilinx': ('yosys', 'nextpnr'),
    'nextpnr-xilinx-fasm2bels': ('yosys', 'nextpnr')
}

# specify the names to remap to
df_mappings = {
    "project": "project",
    "device": "device",
    "toolchain": "toolchain",
    "resources.BRAM": "bram",
    "resources.CARRY": "carry",
    "resources.DFF": "dff",
    "resources.IOB": "iob",
    "resources.LUT": "lut",
    "resources.PLL": "pll",
    "runtime.synthesis": "synthesis",
    "runtime.packing": "pack",
    "runtime.placement": "place",
    "runtime.routing": "route",
    "runtime.fasm": "fasm",
    "runtime.bitstream": "bitstream",
    "runtime.total": "total"
}

# specify the types to cast to
df_types = {
    "project": str,
    "device": str,
    "toolchain": str,
    "freq": float,
    "bram": int,
    "carry": int,
    "dff": int,
    "iob": int,
    "lut": int,
    "pll": int,
    "synthesis": float,
    "pack": float,
    "place": float,
    "route": float,
    "fasm": float,
    "bitstream": float,
    "total": float
}

# %%
# define the pipeline to process the evaluation
processing_pipeline = [
    StandardizeTypes(df_types),
    CleanDuplicates(
        duplicate_col_names=["project", "toolchain"],
        sort_col_names=["freq"]),
    AddNormalizedColumn(
        groupby="project", 
        input_col_name="freq", 
        output_col_name="normalized_max_freq"),
    ExpandColumn(
        input_col_name="toolchain", 
        output_col_names=("synthesis_tool", "pr_tool"),
        mapping=toolchain_map),
    Reindex(["project", "synthesis_tool", "pr_tool", "toolchain"]),
    SortIndex(["project", "synthesis_tool"])
]

# %%
# fetch and process eval
eval1 = HydraFetcher(
    eval_num=1, 
    mapping=df_mappings, 
    hydra_clock_names=hydra_clock_names).get_evaluation()
eval1 = eval1.process(processing_pipeline)

eval2 = HydraFetcher(
    eval_num=3, 
    mapping=df_mappings, 
    hydra_clock_names=hydra_clock_names).get_evaluation()
eval2 = eval2.process(processing_pipeline)
# Out:
# Warning: Unable to get build 1430
# Warning: Unable to get build 1428
# Warning: Unable to get build 1312
# Warning: Unable to get build 1355

# %%
import numpy as np
eval1_nums = eval1.get_df().select_dtypes(include=[np.number])
eval2_nums = eval2.get_df().select_dtypes(include=[np.number])
diff = eval2_nums - eval1_nums
difference_eval = Evaluation(diff)
diff
# Out:
# 12
#                                        vivado  yosys-vivado               1.00
#                                        vpr     vpr                        0.01
#                                                vpr-fasm2bels             -0.07
# hamsternz-hdmi          vivado         vivado  vivado                    -2.00
# ibex                    vivado         vivado  vivado                     2.00
#                         yosys          vpr     vpr                      -10.18
# litex-linux             vivado         vivado  vivado                     0.00
#                         yosys          vivado  yosys-vivado               0.00
#                                        vpr     vpr                       22.98
#                                                vpr-fasm2bels             24.12
# murax                   vivado         vivado  vivado                     0.00
#                         yosys          vivado  yosys-vivado              -2.00
#                                        vpr     vpr                       -0.29
# oneblink                vivado         vivado  vivado                     6.00
#                         yosys          nextpnr nextpnr-ice40               NaN
#                                        vivado  yosys-vivado               4.00
#                                        vpr     vpr                       -0.08
#                                                vpr-fasm2bels              0.01
# picorv32-wrap           vivado         vivado  vivado                     1.00
#                         yosys          vivado  yosys-vivado              -3.00
#                                        vpr     vpr                       -0.87
# picosoc-simpleuart-wrap vivado         vivado  vivado                    -1.00
#                         yosys          vivado  yosys-vivado               0.00
#                                        vpr     vpr                       -0.14
# picosoc-spimemio-wrap   vivado         vivado  vivado                     0.00
#                         yosys          vivado  yosys-vivado               1.00
#                                        vpr     vpr                       -0.45
# picosoc-wrap            vivado         vivado  vivado                    -2.00
#                         yosys          vivado  yosys-vivado              -2.00
#                                        vpr     vpr                       -0.22
# vexriscv-smp            vivado         vivado  vivado                     4.00
# vexriscv-verilog        vivado         vivado  vivado                     4.00
#                         yosys          nextpnr nextpnr-xilinx            -3.98
#                                        vivado  yosys-vivado               1.00
#                                        vpr     vpr                       -4.92
#
#                                                                           fasm  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                      NaN
#                         yosys          nextpnr nextpnr-xilinx              NaN
#                                                nextpnr-xilinx-fasm2bels    NaN
#                                        vivado  yosys-vivado                NaN
#                                        vpr     vpr                       0.870
#                                                vpr-fasm2bels            -2.014
# hamsternz-hdmi          vivado         vivado  vivado                      NaN
# ibex                    vivado         vivado  vivado                      NaN
#                         yosys          vpr     vpr                      -2.400
# litex-linux             vivado         vivado  vivado                      NaN
#                         yosys          vivado  yosys-vivado                NaN
#                                        vpr     vpr                       3.149
#                                                vpr-fasm2bels            -1.202
# murax                   vivado         vivado  vivado                      NaN
#                         yosys          vivado  yosys-vivado                NaN
#                                        vpr     vpr                       0.510
# oneblink                vivado         vivado  vivado                      NaN
#                         yosys          nextpnr nextpnr-ice40               NaN
#                                        vivado  yosys-vivado                NaN
#                                        vpr     vpr                      -1.221
#                                                vpr-fasm2bels            -0.253
# picorv32-wrap           vivado         vivado  vivado                      NaN
#                         yosys          vivado  yosys-vivado                NaN
#                                        vpr     vpr                      -0.958
# picosoc-simpleuart-wrap vivado         vivado  vivado                      NaN
#                         yosys          vivado  yosys-vivado                NaN
#                                        vpr     vpr                      -0.117
# picosoc-spimemio-wrap   vivado         vivado  vivado                      NaN
#                         yosys          vivado  yosys-vivado                NaN
#                                        vpr     vpr                      -1.606
# picosoc-wrap            vivado         vivado  vivado                      NaN
#                         yosys          vivado  yosys-vivado                NaN
#                                        vpr     vpr                      -1.915
# vexriscv-smp            vivado         vivado  vivado                      NaN
# vexriscv-verilog        vivado         vivado  vivado                      NaN
#                         yosys          nextpnr nextpnr-xilinx              NaN
#                                        vivado  yosys-vivado                NaN
#                                        vpr     vpr                      -5.364
#
#                                                                          bitstream  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                        0.000
#                         yosys          nextpnr nextpnr-xilinx               -0.218
#                                                nextpnr-xilinx-fasm2bels      0.111
#                                        vivado  yosys-vivado                  1.000
#                                        vpr     vpr                           0.181
#                                                vpr-fasm2bels                 0.066
# hamsternz-hdmi          vivado         vivado  vivado                       -1.000
# ibex                    vivado         vivado  vivado                        1.000
#                         yosys          vpr     vpr                          -5.256
# litex-linux             vivado         vivado  vivado                        0.000
#                         yosys          vivado  yosys-vivado                  0.000
#                                        vpr     vpr                          16.243
#                                                vpr-fasm2bels                11.312
# murax                   vivado         vivado  vivado                        1.000
#                         yosys          vivado  yosys-vivado                 -1.000
#                                        vpr     vpr                           0.794
# oneblink                vivado         vivado  vivado                        1.000
#                         yosys          nextpnr nextpnr-ice40                   NaN
#                                        vivado  yosys-vivado                 -1.000
#                                        vpr     vpr                          -0.094
#                                                vpr-fasm2bels                 0.030
# picorv32-wrap           vivado         vivado  vivado                        1.000
#                         yosys          vivado  yosys-vivado                  0.000
#                                        vpr     vpr                          -1.223
# picosoc-simpleuart-wrap vivado         vivado  vivado                       -1.000
#                         yosys          vivado  yosys-vivado                  0.000
#                                        vpr     vpr                          -0.177
# picosoc-spimemio-wrap   vivado         vivado  vivado                        0.000
#                         yosys          vivado  yosys-vivado                  0.000
#                                        vpr     vpr                          -0.361
# picosoc-wrap            vivado         vivado  vivado                       -1.000
#                         yosys          vivado  yosys-vivado                 -1.000
#                                        vpr     vpr                          -3.129
# vexriscv-smp            vivado         vivado  vivado                        1.000
# vexriscv-verilog        vivado         vivado  vivado                        0.000
#                         yosys          nextpnr nextpnr-xilinx               -5.130
#                                        vivado  yosys-vivado                  1.000
#                                        vpr     vpr                          -8.465
#
#                                                                            total  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                     -7.681
#                         yosys          nextpnr nextpnr-xilinx             -1.411
#                                                nextpnr-xilinx-fasm2bels    4.330
#                                        vivado  yosys-vivado                2.370
#                                        vpr     vpr                         2.979
#                                                vpr-fasm2bels              -2.046
# hamsternz-hdmi          vivado         vivado  vivado                      0.039
# ibex                    vivado         vivado  vivado                     12.604
#                         yosys          vpr     vpr                       -39.937
# litex-linux             vivado         vivado  vivado                      7.003
#                         yosys          vivado  yosys-vivado                0.280
#                                        vpr     vpr                        92.058
#                                                vpr-fasm2bels             908.540
# murax                   vivado         vivado  vivado                      4.952
#                         yosys          vivado  yosys-vivado              -12.040
#                                        vpr     vpr                         0.609
# oneblink                vivado         vivado  vivado                     14.694
#                         yosys          nextpnr nextpnr-ice40               0.136
#                                        vivado  yosys-vivado               -2.820
#                                        vpr     vpr                        -3.613
#                                                vpr-fasm2bels              -4.617
# picorv32-wrap           vivado         vivado  vivado                     19.768
#                         yosys          vivado  yosys-vivado              -16.780
#                                        vpr     vpr                        -7.681
# picosoc-simpleuart-wrap vivado         vivado  vivado                    -12.831
#                         yosys          vivado  yosys-vivado               -4.820
#                                        vpr     vpr                        -0.263
# picosoc-spimemio-wrap   vivado         vivado  vivado                     -0.314
#                         yosys          vivado  yosys-vivado                6.180
#                                        vpr     vpr                        -6.318
# picosoc-wrap            vivado         vivado  vivado                    -24.790
#                         yosys          vivado  yosys-vivado               -3.900
#                                        vpr     vpr                       -16.416
# vexriscv-smp            vivado         vivado  vivado                     57.460
# vexriscv-verilog        vivado         vivado  vivado                     20.437
#                         yosys          nextpnr nextpnr-xilinx            -23.725
#                                        vivado  yosys-vivado                8.980
#                                        vpr     vpr                       -43.619
#
#                                                                          freq  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                    0.00
#                         yosys          nextpnr nextpnr-xilinx            0.00
#                                                nextpnr-xilinx-fasm2bels  0.00
#                                        vivado  yosys-vivado              0.00
#                                        vpr     vpr                       0.00
#                                                vpr-fasm2bels             0.00
# hamsternz-hdmi          vivado         vivado  vivado                    0.00
# ibex                    vivado         vivado  vivado                    0.00
#                         yosys          vpr     vpr                        NaN
# litex-linux             vivado         vivado  vivado                    0.00
#                         yosys          vivado  yosys-vivado              0.00
#                                        vpr     vpr                       0.00
#                                                vpr-fasm2bels             0.00
# murax                   vivado         vivado  vivado                    0.00
#                         yosys          vivado  yosys-vivado              0.00
#                                        vpr     vpr                       0.00
# oneblink                vivado         vivado  vivado                     NaN
#                         yosys          nextpnr nextpnr-ice40             0.00
#                                        vivado  yosys-vivado               NaN
#                                        vpr     vpr                       0.00
#                                                vpr-fasm2bels             0.00
# picorv32-wrap           vivado         vivado  vivado                     NaN
#                         yosys          vivado  yosys-vivado               NaN
#                                        vpr     vpr                       0.00
# picosoc-simpleuart-wrap vivado         vivado  vivado                     NaN
#                         yosys          vivado  yosys-vivado               NaN
#                                        vpr     vpr                       0.00
# picosoc-spimemio-wrap   vivado         vivado  vivado                     NaN
#                         yosys          vivado  yosys-vivado               NaN
#                                        vpr     vpr                       0.00
# picosoc-wrap            vivado         vivado  vivado                    0.00
#                         yosys          vivado  yosys-vivado              0.00
#                                        vpr     vpr                       0.00
# vexriscv-smp            vivado         vivado  vivado                    0.00
# vexriscv-verilog        vivado         vivado  vivado                     NaN
#                         yosys          nextpnr nextpnr-xilinx           -1.04
#                                        vivado  yosys-vivado               NaN
#                                        vpr     vpr                       0.00
#
#                                                                          normalized_max_freq
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                               0.000000
#                         yosys          nextpnr nextpnr-xilinx                       0.000000
#                                                nextpnr-xilinx-fasm2bels             0.000000
#                                        vivado  yosys-vivado                         0.000000
#                                        vpr     vpr                                  0.000000
#                                                vpr-fasm2bels                        0.000000
# hamsternz-hdmi          vivado         vivado  vivado                               0.000000
# ibex                    vivado         vivado  vivado                               0.000000
#                         yosys          vpr     vpr                                       NaN
# litex-linux             vivado         vivado  vivado                               0.000000
#                         yosys          vivado  yosys-vivado                         0.000000
#                                        vpr     vpr                                  0.000000
#                                                vpr-fasm2bels                        0.000000
# murax                   vivado         vivado  vivado                               0.000000
#                         yosys          vivado  yosys-vivado                         0.000000
#                                        vpr     vpr                                  0.000000
# oneblink                vivado         vivado  vivado                                    NaN
#                         yosys          nextpnr nextpnr-ice40                        0.000000
#                                        vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                  0.000000
#                                                vpr-fasm2bels                        0.000000
# picorv32-wrap           vivado         vivado  vivado                                    NaN
#                         yosys          vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                  0.000000
# picosoc-simpleuart-wrap vivado         vivado  vivado                                    NaN
#                         yosys          vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                  0.000000
# picosoc-spimemio-wrap   vivado         vivado  vivado                                    NaN
#                         yosys          vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                  0.000000
# picosoc-wrap            vivado         vivado  vivado                               0.000000
#                         yosys          vivado  yosys-vivado                         0.000000
#                                        vpr     vpr                                  0.000000
# vexriscv-smp            vivado         vivado  vivado                               0.000000
# vexriscv-verilog        vivado         vivado  vivado                                    NaN
#                         yosys          nextpnr nextpnr-xilinx                       0.000000
#                                        vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                  0.006929

# %%
# generate styling
styled_columns = {
    "bram": 1,
    "carry": 1,
    "dff": 1,
    "iob": 1,
    "lut": 1,
    "synthesis": 1,
    "pack": 1,
    "place": 1,
    "route": 1,
    "fasm": 1,
    "bitstream": 1,
    "total": 1,
    "freq": -1,
    "normalized_max_freq": -1
}

cmap = sns.diverging_palette(180, 0, s=75, l=75, sep=100, as_cmap=True)

styled_eval = difference_eval.process([
    NormalizeAround(
        styled_columns,
        group_by="project",
        idx_name="synthesis_tool",
        idx_value="vivado"),
    ColorMapStyle(cmap)
    ])

# %%
custom_styles = [
    dict(selector="tr:hover", props=[("background-color", "#99ddff")]),
    dict(selector=".level0", props=[("border-bottom", "1px solid black")]),
    dict(selector=".level1", props=[("border-bottom", "1px solid black")]),
    dict(selector=".level2", props=[("border-bottom", "1px solid black")]),
    dict(selector=".level3", props=[("border-bottom", "1px solid black")])
]
vis = SingleTableVisualizer(eval1, styled_eval, version_info=False, custom_styles=custom_styles)
display(vis.get_visualization())
# Out:
# <style  type="text/css" >
#     #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cb tr:hover {
#           background-color: #99ddff;
#     }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cb .level0 {
#           border-bottom: 1px solid black;
#     }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cb .level1 {
#           border-bottom: 1px solid black;
#     }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cb .level2 {
#           border-bottom: 1px solid black;
#     }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cb .level3 {
#           border-bottom: 1px solid black;
#     }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow0_col6 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow0_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow0_col8 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow0_col9 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow0_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow0_col11 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow0_col12 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow1_col6 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow1_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow1_col9 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow1_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow1_col11 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow1_col12 {
#             background-color:  #f8dae0;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow2_col6 {
#             background-color:  #f3bbc6;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow2_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow2_col9 {
#             background-color:  #fae3e8;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow2_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow2_col11 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow2_col12 {
#             background-color:  #efa3b2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow3_col6 {
#             background-color:  #f3b6c2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow3_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow3_col8 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow3_col9 {
#             background-color:  #efa3b2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow3_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow3_col11 {
#             background-color:  #efa3b2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow3_col12 {
#             background-color:  #f2b5c1;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow4_col6 {
#             background-color:  #efa3b2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow4_col9 {
#             background-color:  #f9dce2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow4_col11 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow4_col12 {
#             background-color:  #f1b0bd;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow5_col6 {
#             background-color:  #f5c6cf;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow5_col9 {
#             background-color:  #fae1e6;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow5_col11 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow5_col12 {
#             background-color:  #f9e0e5;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow6_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow6_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow7_col6 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow7_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow7_col8 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow7_col9 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow7_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow7_col11 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow7_col12 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow8_col6 {
#             background-color:  #61c9bd;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow8_col8 {
#             background-color:  #61c9bd;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow8_col9 {
#             background-color:  #61c9bd;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow8_col11 {
#             background-color:  #61c9bd;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow8_col12 {
#             background-color:  #61c9bd;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow8_col13 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow8_col14 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow9_col6 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow9_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow9_col8 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow9_col9 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow9_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow9_col11 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow9_col12 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow10_col6 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow10_col7 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow10_col8 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow10_col9 {
#             background-color:  #f2f2f2;
#             : ;
#         }    #T_0e962f42_bfc5_11ea_a4ec_000d3a9d27cbrow10_col10 {
#             : ;
#             background-color:  yellow;
#         }    #T_0e962f42_bfc5
