# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

from ftpvl.evaluation import Evaluation
from ftpvl.fetchers import HydraFetcher
from ftpvl.processors import *
from ftpvl.styles import ColorMapStyle
from ftpvl.visualizers import DebugVisualizer

import seaborn as sns

# %%
# the ordered list of clock names to reference
hydra_clock_names = ["clk", "sys_clk", "clk_i"]

# specify how to convert toolchains to synthesis_tool/pr_tool
toolchain_map = {
    'vpr': ('yosys', 'vpr'),
    'vpr-fasm2bels': ('yosys', 'vpr'),
    'yosys-vivado': ('yosys', 'vivado'),
    'vivado': ('vivado', 'vivado'),
    'nextpnr-ice40': ('yosys', 'nextpnr'),
    'nextpnr-xilinx': ('yosys', 'nextpnr'),
    'nextpnr-xilinx-fasm2bels': ('yosys', 'nextpnr')
}

# specify the names to remap to
df_mappings = {
    "project": "project",
    "device": "device",
    "toolchain": "toolchain",
    "resources.BRAM": "bram",
    "resources.CARRY": "carry",
    "resources.DFF": "dff",
    "resources.IOB": "iob",
    "resources.LUT": "lut",
    "resources.PLL": "pll",
    "runtime.synthesis": "synthesis",
    "runtime.packing": "pack",
    "runtime.placement": "place",
    "runtime.routing": "route",
    "runtime.fasm": "fasm",
    "runtime.bitstream": "bitstream",
    "runtime.total": "total"
}

# specify the types to cast to
df_types = {
    "project": str,
    "device": str,
    "toolchain": str,
    "freq": float,
    "bram": int,
    "carry": int,
    "dff": int,
    "iob": int,
    "lut": int,
    "pll": int,
    "synthesis": float,
    "pack": float,
    "place": float,
    "route": float,
    "fasm": float,
    "bitstream": float,
    "total": float
}

# %%
# define the pipeline to process the evaluation
processing_pipeline = [
    StandardizeTypes(df_types),
    CleanDuplicates(
        duplicate_col_names=["project", "toolchain"],
        sort_col_names=["freq"]),
    AddNormalizedColumn(
        groupby="project", 
        input_col_name="freq", 
        output_col_name="normalized_max_freq"),
    ExpandColumn(
        input_col_name="toolchain", 
        output_col_names=("synthesis_tool", "pr_tool"),
        mapping=toolchain_map),
    Reindex(["project", "synthesis_tool", "pr_tool", "toolchain"]),
    SortIndex(["project", "synthesis_tool"])
]

# %%
# fetch and process eval
eval1 = HydraFetcher(
    eval_num=2, 
    mapping=df_mappings, 
    hydra_clock_names=hydra_clock_names).get_evaluation()
eval1 = eval1.process(processing_pipeline)

eval2 = HydraFetcher(
    eval_num=4, 
    mapping=df_mappings, 
    hydra_clock_names=hydra_clock_names).get_evaluation()
eval2 = eval2.process(processing_pipeline)
# Out:
# Warning: Unable to get build 1430. It might have failed.
# Warning: Unable to get build 1428. It might have failed.
# Warning: Unable to get build 1312. It might have failed.
# Warning: Unable to get build 1355. It might have failed.

# %%
diff = eval2.process([RelativeDiff(eval1)])
diff.get_df()
# Out:
# vivado  vivado                    0.117647
#                         yosys          vpr     vpr                      -0.123965
# litex-linux             vivado         vivado  vivado                    0.000000
#                         yosys          vivado  yosys-vivado              0.000000
#                                        vpr     vpr                       0.136835
#                                                vpr-fasm2bels             0.153777
# murax                   vivado         vivado  vivado                    0.000000
#                         yosys          vivado  yosys-vivado             -0.125000
#                                        vpr     vpr                      -0.027540
# oneblink                vivado         vivado  vivado                    0.071429
#                         yosys          nextpnr nextpnr-ice40                  NaN
#                                        vivado  yosys-vivado              0.400000
#                                        vpr     vpr                      -0.077670
#                                                vpr-fasm2bels             0.009346
# picorv32-wrap           vivado         vivado  vivado                    0.777778
#                         yosys          vivado  yosys-vivado             -0.187500
#                                        vpr     vpr                      -0.101163
# picosoc-simpleuart-wrap vivado         vivado  vivado                   -0.071429
#                         yosys          vivado  yosys-vivado              0.000000
#                                        vpr     vpr                      -0.042042
# picosoc-spimemio-wrap   vivado         vivado  vivado                    0.000000
#                         yosys          vivado  yosys-vivado              0.071429
#                                        vpr     vpr                      -0.104651
# picosoc-wrap            vivado         vivado  vivado                   -0.086957
#                         yosys          vivado  yosys-vivado             -0.090909
#                                        vpr     vpr                      -0.010223
# vexriscv-smp            vivado         vivado  vivado                    0.088889
# vexriscv-verilog        vivado         vivado  vivado                    0.250000
#                         yosys          nextpnr nextpnr-xilinx           -0.078470
#                                        vivado  yosys-vivado              0.066667
#                                        vpr     vpr                      -0.146647
#
#                                                                              fasm  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                         NaN
#                         yosys          nextpnr nextpnr-xilinx                 NaN
#                                                nextpnr-xilinx-fasm2bels       NaN
#                                        vivado  yosys-vivado                   NaN
#                                        vpr     vpr                       0.033180
#                                                vpr-fasm2bels            -0.076210
# hamsternz-hdmi          vivado         vivado  vivado                         NaN
# ibex                    vivado         vivado  vivado                         NaN
#                         yosys          vpr     vpr                      -0.056184
# litex-linux             vivado         vivado  vivado                         NaN
#                         yosys          vivado  yosys-vivado                   NaN
#                                        vpr     vpr                       0.048446
#                                                vpr-fasm2bels            -0.019744
# murax                   vivado         vivado  vivado                         NaN
#                         yosys          vivado  yosys-vivado                   NaN
#                                        vpr     vpr                       0.017433
# oneblink                vivado         vivado  vivado                         NaN
#                         yosys          nextpnr nextpnr-ice40                  NaN
#                                        vivado  yosys-vivado                   NaN
#                                        vpr     vpr                      -0.067044
#                                                vpr-fasm2bels            -0.013782
# picorv32-wrap           vivado         vivado  vivado                         NaN
#                         yosys          vivado  yosys-vivado                   NaN
#                                        vpr     vpr                      -0.032678
# picosoc-simpleuart-wrap vivado         vivado  vivado                         NaN
#                         yosys          vivado  yosys-vivado                   NaN
#                                        vpr     vpr                      -0.004642
# picosoc-spimemio-wrap   vivado         vivado  vivado                         NaN
#                         yosys          vivado  yosys-vivado                   NaN
#                                        vpr     vpr                      -0.061053
# picosoc-wrap            vivado         vivado  vivado                         NaN
#                         yosys          vivado  yosys-vivado                   NaN
#                                        vpr     vpr                      -0.058733
# vexriscv-smp            vivado         vivado  vivado                         NaN
# vexriscv-verilog        vivado         vivado  vivado                         NaN
#                         yosys          nextpnr nextpnr-xilinx                 NaN
#                                        vivado  yosys-vivado                   NaN
#                                        vpr     vpr                      -0.139906
#
#                                                                          bitstream  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                     0.000000
#                         yosys          nextpnr nextpnr-xilinx            -0.137021
#                                                nextpnr-xilinx-fasm2bels   0.072644
#                                        vivado  yosys-vivado               0.125000
#                                        vpr     vpr                        0.102899
#                                                vpr-fasm2bels              0.039497
# hamsternz-hdmi          vivado         vivado  vivado                    -0.062500
# ibex                    vivado         vivado  vivado                     0.111111
#                         yosys          vpr     vpr                       -0.049093
# litex-linux             vivado         vivado  vivado                     0.000000
#                         yosys          vivado  yosys-vivado               0.000000
#                                        vpr     vpr                        0.102064
#                                                vpr-fasm2bels              0.077008
# murax                   vivado         vivado  vivado                     0.125000
#                         yosys          vivado  yosys-vivado              -0.111111
#                                        vpr     vpr                        0.033416
# oneblink                vivado         vivado  vivado                     0.000000
#                         yosys          nextpnr nextpnr-ice40                   NaN
#                                        vivado  yosys-vivado              -0.111111
#                                        vpr     vpr                       -0.083039
#                                                vpr-fasm2bels              0.027248
# picorv32-wrap           vivado         vivado  vivado                     0.125000
#                         yosys          vivado  yosys-vivado               0.000000
#                                        vpr     vpr                       -0.053392
# picosoc-simpleuart-wrap vivado         vivado  vivado                    -0.111111
#                         yosys          vivado  yosys-vivado               0.000000
#                                        vpr     vpr                       -0.029843
# picosoc-spimemio-wrap   vivado         vivado  vivado                     0.000000
#                         yosys          vivado  yosys-vivado               0.000000
#                                        vpr     vpr                       -0.065816
# picosoc-wrap            vivado         vivado  vivado                    -0.100000
#                         yosys          vivado  yosys-vivado              -0.090909
#                                        vpr     vpr                       -0.065543
# vexriscv-smp            vivado         vivado  vivado                     0.071429
# vexriscv-verilog        vivado         vivado  vivado                     0.000000
#                         yosys          nextpnr nextpnr-xilinx            -0.102057
#                                        vivado  yosys-vivado               0.111111
#                                        vpr     vpr                       -0.131442
#
#                                                                             total  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                   -0.067232
#                         yosys          nextpnr nextpnr-xilinx           -0.103941
#                                                nextpnr-xilinx-fasm2bels  0.018904
#                                        vivado  yosys-vivado              0.057441
#                                        vpr     vpr                       0.038193
#                                                vpr-fasm2bels            -0.005427
# hamsternz-hdmi          vivado         vivado  vivado                    0.000162
# ibex                    vivado         vivado  vivado                    0.036588
#                         yosys          vpr     vpr                      -0.083792
# litex-linux             vivado         vivado  vivado                    0.022949
#                         yosys          vivado  yosys-vivado              0.001009
#                                        vpr     vpr                       0.100639
#                                                vpr-fasm2bels             0.351880
# murax                   vivado         vivado  vivado                    0.036678
#                         yosys          vivado  yosys-vivado             -0.201270
#                                        vpr     vpr                       0.003635
# oneblink                vivado         vivado  vivado                    0.010920
#                         yosys          nextpnr nextpnr-ice40             0.076967
#                                        vivado  yosys-vivado             -0.071212
#                                        vpr     vpr                      -0.058982
#                                                vpr-fasm2bels            -0.016906
# picorv32-wrap           vivado         vivado  vivado                    0.232187
#                         yosys          vivado  yosys-vivado             -0.276123
#                                        vpr     vpr                      -0.047956
# picosoc-simpleuart-wrap vivado         vivado  vivado                   -0.107474
#                         yosys          vivado  yosys-vivado             -0.104897
#                                        vpr     vpr                      -0.002983
# picosoc-spimemio-wrap   vivado         vivado  vivado                   -0.002479
#                         yosys          vivado  yosys-vivado              0.153770
#                                        vpr     vpr                      -0.068349
# picosoc-wrap            vivado         vivado  vivado                   -0.116898
#                         yosys          vivado  yosys-vivado             -0.038992
#                                        vpr     vpr                      -0.061190
# vexriscv-smp            vivado         vivado  vivado                    0.115667
# vexriscv-verilog        vivado         vivado  vivado                    0.131141
#                         yosys          nextpnr nextpnr-xilinx           -0.116784
#                                        vivado  yosys-vivado              0.152643
#                                        vpr     vpr                      -0.133000
#
#                                                                             freq  \
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                    0.00000
#                         yosys          nextpnr nextpnr-xilinx            0.00000
#                                                nextpnr-xilinx-fasm2bels  0.00000
#                                        vivado  yosys-vivado              0.00000
#                                        vpr     vpr                       0.00000
#                                                vpr-fasm2bels             0.00000
# hamsternz-hdmi          vivado         vivado  vivado                    0.00000
# ibex                    vivado         vivado  vivado                    0.00000
#                         yosys          vpr     vpr                           NaN
# litex-linux             vivado         vivado  vivado                    0.00000
#                         yosys          vivado  yosys-vivado              0.00000
#                                        vpr     vpr                       0.00000
#                                                vpr-fasm2bels             0.00000
# murax                   vivado         vivado  vivado                    0.00000
#                         yosys          vivado  yosys-vivado              0.00000
#                                        vpr     vpr                       0.00000
# oneblink                vivado         vivado  vivado                        NaN
#                         yosys          nextpnr nextpnr-ice40             0.00000
#                                        vivado  yosys-vivado                  NaN
#                                        vpr     vpr                       0.00000
#                                                vpr-fasm2bels             0.00000
# picorv32-wrap           vivado         vivado  vivado                        NaN
#                         yosys          vivado  yosys-vivado                  NaN
#                                        vpr     vpr                       0.00000
# picosoc-simpleuart-wrap vivado         vivado  vivado                        NaN
#                         yosys          vivado  yosys-vivado                  NaN
#                                        vpr     vpr                       0.00000
# picosoc-spimemio-wrap   vivado         vivado  vivado                        NaN
#                         yosys          vivado  yosys-vivado                  NaN
#                                        vpr     vpr                       0.00000
# picosoc-wrap            vivado         vivado  vivado                    0.00000
#                         yosys          vivado  yosys-vivado              0.00000
#                                        vpr     vpr                       0.00000
# vexriscv-smp            vivado         vivado  vivado                    0.00000
# vexriscv-verilog        vivado         vivado  vivado                        NaN
#                         yosys          nextpnr nextpnr-xilinx           -0.01293
#                                        vivado  yosys-vivado                  NaN
#                                        vpr     vpr                       0.00000
#
#                                                                          normalized_max_freq
# project                 synthesis_tool pr_tool toolchain
# blinky                  vivado         vivado  vivado                                 0.0000
#                         yosys          nextpnr nextpnr-xilinx                         0.0000
#                                                nextpnr-xilinx-fasm2bels               0.0000
#                                        vivado  yosys-vivado                           0.0000
#                                        vpr     vpr                                    0.0000
#                                                vpr-fasm2bels                          0.0000
# hamsternz-hdmi          vivado         vivado  vivado                                 0.0000
# ibex                    vivado         vivado  vivado                                 0.0000
#                         yosys          vpr     vpr                                       NaN
# litex-linux             vivado         vivado  vivado                                 0.0000
#                         yosys          vivado  yosys-vivado                           0.0000
#                                        vpr     vpr                                    0.0000
#                                                vpr-fasm2bels                          0.0000
# murax                   vivado         vivado  vivado                                 0.0000
#                         yosys          vivado  yosys-vivado                           0.0000
#                                        vpr     vpr                                    0.0000
# oneblink                vivado         vivado  vivado                                    NaN
#                         yosys          nextpnr nextpnr-ice40                          0.0000
#                                        vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                    0.0000
#                                                vpr-fasm2bels                          0.0000
# picorv32-wrap           vivado         vivado  vivado                                    NaN
#                         yosys          vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                    0.0000
# picosoc-simpleuart-wrap vivado         vivado  vivado                                    NaN
#                         yosys          vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                    0.0000
# picosoc-spimemio-wrap   vivado         vivado  vivado                                    NaN
#                         yosys          vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                    0.0000
# picosoc-wrap            vivado         vivado  vivado                                 0.0000
#                         yosys          vivado  yosys-vivado                           0.0000
#                                        vpr     vpr                                    0.0000
# vexriscv-smp            vivado         vivado  vivado                                 0.0000
# vexriscv-verilog        vivado         vivado  vivado                                    NaN
#                         yosys          nextpnr nextpnr-xilinx                         0.0000
#                                        vivado  yosys-vivado                              NaN
#                                        vpr     vpr                                    0.0131

# %%
# generate styling
styled_columns = {
    "bram": 1,
    "carry": 1,
    "dff": 1,
    "iob": 1,
    "lut": 1,
    "synthesis": 1,
    "pack": 1,
    "place": 1,
    "route": 1,
    "fasm": 1,
    "bitstream": 1,
    "total": 1,
    "freq": -1,
    "normalized_max_freq": -1
}

cmap = sns.diverging_palette(180, 0, s=75, l=75, sep=100, as_cmap=True)

styled_eval = diff.process([
    Normalize(styled_columns),
    ColorMapStyle(cmap)
    ])

# %%
custom_styles = [
    dict(selector="tr:hover", props=[("background-color", "#99ddff")]),
    dict(selector=".level0", props=[("border-bottom", "1px solid black")]),
    dict(selector=".level1", props=[("border-bottom", "1px solid black")]),
    dict(selector=".level2", props=[("border-bottom", "1px solid black")]),
    dict(selector=".level3", props=[("border-bottom", "1px solid black")])
]
vis = DebugVisualizer(diff, version_info=False, custom_styles=custom_styles, column_order=styled_columns.keys())
display(vis.get_visualization())
# Out:
# <style  type="text/css" >
#     #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954b tr:hover {
#           background-color: #99ddff;
#     }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954b .level0 {
#           border-bottom: 1px solid black;
#     }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954b .level1 {
#           border-bottom: 1px solid black;
#     }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954b .level2 {
#           border-bottom: 1px solid black;
#     }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954b .level3 {
#           border-bottom: 1px solid black;
#     }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow0_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow0_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow0_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow0_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow1_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow1_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow1_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow2_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow2_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow2_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow3_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow3_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow3_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow3_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow4_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow5_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow6_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow6_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow7_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow7_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow8_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow8_col12 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow8_col13 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow9_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow9_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow10_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow10_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow13_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow13_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow13_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow14_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow14_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow14_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow16_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow16_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow16_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow16_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow16_col12 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow16_col13 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow17_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow17_col5 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow17_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow17_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow17_col8 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow17_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow17_col10 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow18_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow18_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow18_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow18_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow18_col12 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow18_col13 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow19_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow20_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow21_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow21_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow21_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow21_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow21_col12 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow21_col13 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow22_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow22_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow22_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow22_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow22_col12 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow22_col13 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow23_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow24_col0 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow24_col6 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow24_col7 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow24_col9 {
#             background-color:  yellow;
#         }    #T_dcc8c95e_c792_11ea_b9bb_3e22fb79954brow24_col12 {
#             background-color:  yellow;
